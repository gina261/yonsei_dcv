# %%
import os
import cv2
import matplotlib.pyplot as plt

# %%
a = cv2.imread("./images/baboon.png")
a_plt = plt.imread("./images/baboon.png")

# %%
plt.imshow(a_plt)

# %%
plt.imshow(a)

# %%
a.shape
# Out:
# (512, 512, 3)

# %%
import numpy as np
suck = np.zeros((a.shape[0], a.shape[1], a.shape[2]), dtype = "uint8")

# %%
suck[:,:,0] = a[:,:,2]
suck[:,:,2] = a[:,:,1]
suck[:,:,1] = a[:,:,0]

# %%
plt.imshow(suck)
